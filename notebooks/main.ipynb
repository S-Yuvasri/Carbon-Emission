# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
data=pd.read_csv("co2 Emission.csv")
data.head(10)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0        4.0          AS5
# 1  ACURA         ILX       COMPACT             2.4        4.0           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5        4.0          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5        6.0          AS6
# 4  ACURA     MDX 4WD     SUV-SMALL             3.5        6.0          AS6
# 5  ACURA     RDX AWD   SUV - SMALL             3.5        6.0          AS6
# 6  ACURA         RLX      MID-SIZE             3.5        6.0          AS6
# 7  ACURA          TL      MID-SIZE             3.5        6.0          AS6
# 8  ACURA      TL AWD      MID-SIZE             3.7        6.0          AS6
# 9  ACURA      TL AWD      MID-SIZE             3.7        6.0           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# ...

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -------- ------------------------------- 1.6/7.8 MB 10.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.1/7.8 MB 7.4 MB/s eta 0:00:01
#    -------------------- ------------------- 3.9/7.8 MB 6.5 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.8 MB 5.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/7.8 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 5.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------------------------- ------ 1.8/2.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 7.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.6 MB 11.2 MB/s eta 0:00:01
# ...

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
x=data[['Make','Model','Vehicle Class','Engine Size(L)','Cylinders','Transmission','Fuel Type','Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)','Fuel Consumption Comb (mpg)','CO2 Emissions(g/km)']].values
x
# Out:
# array([['ACURA', 'ILX', 'COMPACT', ..., 8.5, 33.0, 196.0],
#        ['ACURA', 'ILX', 'COMPACT', ..., 9.6, 29.0, 221.0],
#        ['ACURA', 'ILX HYBRID', 'COMPACT', ..., 5.9, 48.0, 136.0],
#        ...,
#        ['VOLVO', 'XC90 T5 AWD', 'SUV - STANDARD', ..., 9.9, 29.0, 232.0],
#        ['VOLVO', 'XC90 T6 AWD', 'SUV - STANDARD', ..., 10.7, 26.0, 248.0],
#        ['VOLVO', 'V60 T5', 'STATION WAGON - SMALL', ..., 8.9, 32.0,
#         208.0]], dtype=object)

# %%
y=data[['Fuel Type']].values
y
# Out:
# array([['Z'],
#        ['Z'],
#        ['Z'],
#        ...,
#        ['Z'],
#        ['Z'],
#        ['Z']], dtype=object)

# %%
data.shape
# Out:
# (7468, 12)

# %%
df=data.isnull()
df
# Out:
#        Make  Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0     False  False          False           False      False         False
# 1     False  False          False           False      False         False
# 2     False  False          False           False      False         False
# 3     False  False          False           False      False         False
# 4     False  False          False           False      False         False
# ...     ...    ...            ...             ...        ...           ...
# 7463  False  False          False           False      False         False
# 7464  False  False          False           False      False         False
# 7465  False  False          False           False      False         False
# 7466  False  False          False           False      False         False
# 7467  False  False          False           False      False         False
#
#       Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
df=data.isnull().sum()
df
# Out:
# Make                                16
# Model                               16
# Vehicle Class                       16
# Engine Size(L)                      17
# Cylinders                           17
# Transmission                        16
# Fuel Type                           16
# Fuel Consumption City (L/100 km)    19
# Fuel Consumption Hwy (L/100 km)     19
# Fuel Consumption Comb (L/100 km)    20
# Fuel Consumption Comb (mpg)         20
# CO2 Emissions(g/km)                 20
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
re=data.dropna(how="all")
re
# Out:
#        Make        Model          Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX                COMPACT             2.0        4.0
# 1     ACURA          ILX                COMPACT             2.4        4.0
# 2     ACURA   ILX HYBRID                COMPACT             1.5        4.0
# 3     ACURA      MDX 4WD            SUV - SMALL             3.5        6.0
# 4     ACURA      MDX 4WD              SUV-SMALL             3.5        6.0
# ...     ...          ...                    ...             ...        ...
# 7463  VOLVO  XC60 T5 AWD            SUV - SMALL             2.0        4.0
# 7464  VOLVO  XC60 T6 AWD            SUV - SMALL             2.0        4.0
# 7465  VOLVO  XC90 T5 AWD         SUV - STANDARD             2.0        4.0
# 7466  VOLVO  XC90 T6 AWD         SUV - STANDARD             2.0        4.0
# 7467  VOLVO       V60 T5  STATION WAGON - SMALL             2.0        4.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
re.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      1
# Cylinders                           1
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    3
# Fuel Consumption Hwy (L/100 km)     3
# Fuel Consumption Comb (L/100 km)    4
# Fuel Consumption Comb (mpg)         4
# CO2 Emissions(g/km)                 4
# dtype: int64

# %%
hf=data.fillna(method='bfill')
hf
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1028\2937561572.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   hf=data.fillna(method='bfill')
#        Make        Model          Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX                COMPACT             2.0        4.0
# 1     ACURA          ILX                COMPACT             2.4        4.0
# 2     ACURA   ILX HYBRID                COMPACT             1.5        4.0
# 3     ACURA      MDX 4WD            SUV - SMALL             3.5        6.0
# 4     ACURA      MDX 4WD              SUV-SMALL             3.5        6.0
# ...     ...          ...                    ...             ...        ...
# 7463  VOLVO  XC60 T5 AWD            SUV - SMALL             2.0        4.0
# 7464  VOLVO  XC60 T6 AWD            SUV - SMALL             2.0        4.0
# ...

# %%
hf.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7468.000000  7468.000000                       7468.000000
# mean         3.159601     5.613953                         12.555396
# std          1.354033     1.826256                          3.498190
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7468.000000                       7468.000000
# mean                          9.040908                         10.974411
# std                           2.222214                          2.890447
# ...

# %%
hf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7468 entries, 0 to 7467
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7468 non-null   object
#  1   Model                             7468 non-null   object
#  2   Vehicle Class                     7468 non-null   object
#  3   Engine Size(L)                    7468 non-null   float64
#  4   Cylinders                         7468 non-null   float64
#  5   Transmission                      7468 non-null   object
#  6   Fuel Type                         7468 non-null   object
#  7   Fuel Consumption City (L/100 km)  7468 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7468 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7468 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7468 non-null   float64
# ...

# %%
hf.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
numeric_cols=hf.select_dtypes(exclude='object').columns
categorical_cols=hf.select_dtypes(include='object').columns

# %%
hf[numeric_cols]
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0        4.0                               9.9
# 1                2.4        4.0                              11.2
# 2                1.5        4.0                               6.0
# 3                3.5        6.0                              12.7
# 4                3.5        6.0                              12.1
# ...              ...        ...                               ...
# 7463             2.0        4.0                              11.2
# 7464             2.0        4.0                              11.7
# 7465             2.0        4.0                              11.2
# 7466             2.0        4.0                              12.2
# 7467             2.0        4.0                              10.5
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# ...

# %%
hf[categorical_cols]
# Out:
#        Make        Model          Vehicle Class Transmission Fuel Type
# 0     ACURA          ILX                COMPACT          AS5         Z
# 1     ACURA          ILX                COMPACT           M6         Z
# 2     ACURA   ILX HYBRID                COMPACT          AV7         Z
# 3     ACURA      MDX 4WD            SUV - SMALL          AS6         Z
# 4     ACURA      MDX 4WD              SUV-SMALL          AS6         Z
# ...     ...          ...                    ...          ...       ...
# 7463  VOLVO  XC60 T5 AWD            SUV - SMALL          AS8         Z
# 7464  VOLVO  XC60 T6 AWD            SUV - SMALL          AS8         Z
# 7465  VOLVO  XC90 T5 AWD         SUV - STANDARD          AS8         Z
# 7466  VOLVO  XC90 T6 AWD         SUV - STANDARD          AS8         Z
# 7467  VOLVO       V60 T5  STATION WAGON - SMALL          AS8         Z
#
# [7468 rows x 5 columns]

# %%
print(hf[numeric_cols].shape)
print(hf[categorical_cols].shape)
# Out:
# (7468, 7)
# (7468, 5)

# %%
hf['Fuel Type'].unique()
# Out:
# array(['Z', 'D', 'X', 'E', 'N'], dtype=object)

# %%
hf['Fuel Type'] = hf['Fuel Type'].replace({'Z' :4 , 'D' :4, 'X':3, 'E' :2, 'N' : 1})
plt.plot(hf['Fuel Type'])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1028\443763442.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   hf['Fuel Type'] = hf['Fuel Type'].replace({'Z' :4 , 'D' :4, 'X':3, 'E' :2, 'N' : 1})

# %%
hf['Fuel Type'].value_counts()
hf=hf[hf['Fuel Type']!=1]
hf['Fuel Type'].value_counts()
# Out:
# Fuel Type
# 3    3683
# 4    3409
# 2     374
# Name: count, dtype: int64

# %%
fig,ax=plt.subplots()
ax.bar(hf['Fuel Type'].value_counts().index,hf['Fuel Type'].value_counts().values,color=['red','blue','yellow'])
ax.set_xticks(hf['Fuel Type'].value_counts().index)
ax.set_xticklabels(hf['Fuel Type'].value_counts().index)
# Out:
# [Text(3, 0, '3'), Text(4, 0, '4'), Text(2, 0, '2')]

# %%
len(hf['Make'].value_counts())
# Out:
# 42

# %%
slightly_darker_colors = [
    "#E0E8FF", "#E0EFFF", "#E5E5CC", "#EAF8C2", "#EFE1CD", "#EED5A1", "#EED4B0", "#EED4CF", "#EED3AC",
    "#EED2A4", "#EAEAAB", "#EAEAEA", "#EAEAF3", "#EAEAFA", "#EAEAF5", "#EBEAD0", "#EBEBEB", "#EBFEEB",
    "#E8E8FF", "#E0FFE0", "#E9EBCC", "#FFDAB9", "#EFCDB9", "#FFC0AB", "#FFD1C4", "#FFD1A1", "#EAEAAB",
    "#E9EBCC", "#EAEAAB", "#EBEAF3", "#EAF8C2", "#EFE1CD", "#EFEFEF", "#EAEAF5", "#EBEBD0", "#EBD9A2",
    "#EFCDB9", "#EED3AC", "#EED2A4", "#EAEAAB", "#E0E8FF", "#E0EFFF", "#E8E8FF", "#E5E5CC", "#E5E5E5"
]
hf_sorted_by_CO2=hf.sort_values(by='CO2 Emissions(g/km)',ascending=False)
print(hf_sorted_by_CO2[['Make','Model','CO2 Emissions(g/km)']].head())
fix,ax=plt.subplots(figsize=(20,8))
ax.bar(hf_sorted_by_CO2["Make"].value_counts().index,hf_sorted_by_CO2["Make"].value_counts(),color=slightly_darker_colors)
plt.xticks(rotation=90)
plt.show()
# Out:
#              Make               Model  CO2 Emissions(g/km)
# 5638      BUGATTI              Chiron                522.0
# 4559      BUGATTI              CHIRON                522.0
# 6711      BUGATTI              Chiron                522.0
# 7139  LAMBORGHINI  Aventador Roadster                493.0
# 6111  LAMBORGHINI  Aventador Roadster                493.0

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/10.9 MB 13.9 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/10.9 MB 11.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/10.9 MB 7.7 MB/s eta 0:00:01
#    --------------------- ------------------ 5.8/10.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/10.9 MB 6.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/10.9 MB 6.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/10.9 MB 6.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/10.9 MB 4.3 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/10.9 MB 4.2 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/10.9 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/10.9 MB 4.3 MB/s eta 0:00:01
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
hf_sorted_by_CO2['Make']=label.fit_transform(hf_sorted_by_CO2['Make'])
hf_sorted_by_CO2.head()
# Out:
#       Make               Model Vehicle Class  Engine Size(L)  Cylinders  \
# 5638     6              Chiron    TWO-SEATER             8.0       16.0
# 4559     6              CHIRON    TWO-SEATER             8.0       16.0
# 6711     6              Chiron    TWO-SEATER             8.0       16.0
# 7139    22  Aventador Roadster    TWO-SEATER             6.5       12.0
# 6111    22  Aventador Roadster    TWO-SEATER             6.5       12.0
#
#      Transmission  Fuel Type  Fuel Consumption City (L/100 km)  \
# 5638          AM7          4                              26.8
# 4559          AM7          4                              26.8
# 6711          AM7          4                              26.8
# 7139          AM7          4                              26.6
# 6111          AM7          4                              26.6
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 5638                             16.6                              22.2
# ...

# %%
hf_sorted_by_CO2=hf_sorted_by_CO2.drop(hf[['Model','Vehicle Class','Transmission']],axis=1)

# %%
hf_sorted_by_CO2.head()
# Out:
#       Make  Engine Size(L)  Cylinders  Fuel Type  \
# 5638     6             8.0       16.0          4
# 4559     6             8.0       16.0          4
# 6711     6             8.0       16.0          4
# 7139    22             6.5       12.0          4
# 6111    22             6.5       12.0          4
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 5638                              26.8                             16.6
# 4559                              26.8                             16.6
# 6711                              26.8                             16.6
# 7139                              26.6                             15.8
# 6111                              26.6                             15.8
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 5638                              22.2                         13.0
# 4559                              22.2                         13.0
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.pairplot(hf_sorted_by_CO2)
plt.show()

# %%
hf_sorted_by_CO2=hf_sorted_by_CO2[hf_sorted_by_CO2['Engine Size(L)']<7]
hf_sorted_by_CO2=hf_sorted_by_CO2[hf_sorted_by_CO2['Fuel Consumption City (L/100 km)']<25]
#hf_sorted_by_CO2=hf_sorted_by_CO2.drop(['Fuel Consumption Comb (mpg)'],axis=1)

# %%
sns.pairplot(hf_sorted_by_CO2)
plt.show()

# %%
x = hf_sorted_by_CO2.drop(['CO2 Emissions(g/km)'], axis =1)
y = hf_sorted_by_CO2['CO2 Emissions(g/km)']
x.head()
# Out:
#       Make  Engine Size(L)  Cylinders  Fuel Type  \
# 355     13             6.8       10.0          3
# 3010    28             6.0       12.0          4
# 5188    28             6.0       12.0          4
# 4094    28             6.0       12.0          4
# 2470     9             6.0        8.0          3
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 355                               23.9                             17.8
# 3010                              24.3                             17.9
# 5188                              22.2                             18.0
# 4094                              22.2                             18.0
# 2470                              23.0                             16.0
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)
# 355                               21.2                         13.0
# 3010                              21.4                         13.0
# ...

# %%
hf.Make.unique()
# Out:
# array(['ACURA', 'ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW',
#        'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE', 'FIAT',
#        'FORD', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP',
#        'KIA', 'LAMBORGHINI', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MASERATI',
#        'MAZDA', 'MERCEDES-BENZ', 'MINI', 'MITSUBISHI', 'NISSAN',
#        'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION', 'SMART', 'SRT', 'SUBARU',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GENESIS', 'BUGATTI'],
#       dtype=object)

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9255203435306778

# %%
model.score(x_train,y_train)
# Out:
# 0.9226412925266174

# %%
pred = model.predict(x_test)
pred
# Out:
# array([341.50454714, 247.24382329, 357.42652642, ..., 276.84436691,
#        201.85469152, 256.84144205])

# %%
input=([[30,7.0,7.0,4,25.9,10.8,10.2,15.0]])
prediction=model.predict(input)
print(prediction)
# Out:
# [306.44708799]

# %%
from joblib import dump

# %%
dump(model,'./../savedmodels/model.joblib')
# Out:
# ['./../savedmodels/model.joblib']

# %%
'''engine_size = float(input("Enter engine size (in liters): "))
fuel_consumption_city = float(input("Enter fuel consumption in city (in L/100 km): "))
x_test = [[engine_size, fuel_consumption_city]]
pred_emissions = model.predict(x_test)
print("Predicted CO2 Emissions: {:.2f} g/km".format(pred_emissions[0]))'''
# Out:
# 'engine_size = float(input("Enter engine size (in liters): "))\nfuel_consumption_city = float(input("Enter fuel consumption in city (in L/100 km): "))\nx_test = [[engine_size, fuel_consumption_city]]\npred_emissions = model.predict(x_test)\nprint("Predicted CO2 Emissions: {:.2f} g/km".format(pred_emissions[0]))'

# %%
input=([[30,7.0,7.0,4,25.9,10.8,10.2,15.0]])
prediction=model.predict(input)
print(prediction)
if(prediction<=100 or prediction<200):
    print("Less Emission")
elif(prediction<=200 or prediction<300):
    print("Moderate Emission")
elif(prediction<=300 or prediction<400):
    print("High emission")
elif(prediction<=400 or prediction<500):
    print("Very high Emission")
else:
    print("Please give the valid data, any of data you have given is incorrect")
# Out:
# [310.61191388]
# High emission

# %%
'''s = hf_sorted_by_CO2.drop(['CO2 Emissions(g/km)'], axis =1)
v = hf_sorted_by_CO2['CO2 Emissions(g/km)']
s.head()
support=hf_sorted_by_CO2.drop(['Make','Cylinders','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)','Fuel Consumption Comb (mpg)'],axis=1)
support'''
# Out:
# "s = hf_sorted_by_CO2.drop(['CO2 Emissions(g/km)'], axis =1)\nv = hf_sorted_by_CO2['CO2 Emissions(g/km)']\ns.head()\nsupport=hf_sorted_by_CO2.drop(['Make','Cylinders','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)','Fuel Consumption Comb (mpg)'],axis=1)\nsupport"

# %%
'''s=support.drop(['CO2 Emissions(g/km)'],axis=1)
v = support['CO2 Emissions(g/km)']
s
'''
# Out:
# "s=support.drop(['CO2 Emissions(g/km)'],axis=1)\nv = support['CO2 Emissions(g/km)']\ns\n"

# %%
'''from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
s_train, s_test, v_train, v_test = train_test_split(s, v, test_size = 0.2, random_state = 42)'''

# %%
'''from sklearn.svm import SVR
clf = SVR(kernel='linear')  # You can choose different kernels (e.g., 'rbf', 'poly', etc.)
clf.fit(s_train, v_train) '''  # X_train contains features, y_train contains CO2 emissions
# Out:
# SVR(kernel='linear')

# %%
'''clf.score(s_test,v_test)'''
# Out:
# 0.8642676660343889

# %%
'''clf.score(s_train,v_train)'''
# Out:
# 0.8301863940683598

# %%
dec=hf_sorted_by_CO2
dec
# Out:
#       Make  Engine Size(L)  Cylinders  Fuel Type  \
# 355     13             6.8       10.0          3
# 3010    28             6.0       12.0          4
# 5188    28             6.0       12.0          4
# 4094    28             6.0       12.0          4
# 2470     9             6.0        8.0          3
# ...    ...             ...        ...        ...
# 7025    17             1.6        4.0          3
# 5996    17             1.6        4.0          3
# 4955    17             1.6        4.0          3
# 7026    17             1.6        4.0          3
# 3865    17             1.6        4.0          3
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 355                               23.9                             17.8
# 3010                              24.3                             17.9
# 5188                              22.2                             18.0
# 4094                              22.2                             18.0
# ...

# %%
d=dec.drop(['CO2 Emissions(g/km)'],axis=1)
t=dec['CO2 Emissions(g/km)']

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
d_train, d_test, t_train, t_test = train_test_split(d, t, test_size = 0.2, random_state = 42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
dtc = DecisionTreeRegressor()
dtc.fit(d_train, t_train)
#y_pred = dtc.predict(d_test)
# Out:
# DecisionTreeRegressor()

# %%
dtc.score(d_test,t_test)
# Out:
# 0.9969713426280103

# %%
dtc.score(d_train,t_train)
# Out:
# 0.9995605899437449

# %%
'''from sklearn.tree import DecisionTreeRegressor
# Import necessary libraries
#from sklearn.datasets import co2Emission
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load the Iris dataset (you can replace this with your own dataset)
#co2 = co2Emission()


# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a decision tree classifier
clf = DecisionTreeClassifier()

# Fit the model to the training data
clf.fit(x, y_train)

# Make predictions on the test data
y_pred = clf.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Import necessary libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load your dataset (replace 'your_dataset.csv' with your dataset file)
data = pd.read_csv('co2 Emission.csv')

# Assuming your dataset has features and a target variable
# Split the data into features (X) and target variable (y)
x = hf_sorted_by_CO2.drop(['CO2 Emissions(g/km)'], axis =1)
y = hf_sorted_by_CO2['CO2 Emissions(g/km)']

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a decision tree classifier
k = DecisionTreeClassifier()

# Fit the model to the training data
k.fit(x_train, y_train)

# Make predictions on the test data
y_pred = k.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
'''
# Out:
# 'from sklearn.tree import DecisionTreeRegressor\n# Import necessary libraries\n#from sklearn.datasets import co2Emission\nfrom sklearn.tree import DecisionTreeClassifier\nfrom sklearn.model_selection import train_test_split\nfrom sklearn.metrics import accuracy_score\n\n# Load the Iris dataset (you can replace this with your own dataset)\n#co2 = co2Emission()\n\n\n# Split the data into training and testing sets\nx_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)\n\n# Create a decision tree classifier\nclf = DecisionTreeClassifier()\n\n# Fit the model to the training data\nclf.fit(x, y_train)\n\n# Make predictions on the test data\ny_pred = clf.predict(x_test)\n\n# Calculate accuracy\naccuracy = accuracy_score(y_test, y_pred)\nprint(f"Accuracy: {accuracy:.2f}")\n\n# Import necessary libraries\nimport pandas as pd\nfrom sklearn.tree import DecisionTreeClassifier\nfrom sklearn.model_selection import train_test_split\nfrom sklearn.metrics import acc
# ...

# %%
'''k.score(x_test,y_test)'''
# Out:
# 'k.score(x_test,y_test)'

# %%
'''neighbor=hf_sorted_by_CO2
neighbor'''
# Out:
#       Make  Engine Size(L)  Cylinders  Fuel Type  \
# 355     13             6.8       10.0          3
# 3010    28             6.0       12.0          4
# 5188    28             6.0       12.0          4
# 4094    28             6.0       12.0          4
# 2470     9             6.0        8.0          3
# ...    ...             ...        ...        ...
# 7025    17             1.6        4.0          3
# 5996    17             1.6        4.0          3
# 4955    17             1.6        4.0          3
# 7026    17             1.6        4.0          3
# 3865    17             1.6        4.0          3
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 355                               23.9                             17.8
# 3010                              24.3                             17.9
# 5188                              22.2                             18.0
# 4094                              22.2                             18.0
# ...

# %%
'''k=neighbor.drop(['CO2 Emissions(g/km)'],axis=1)
n=neighbor['CO2 Emissions(g/km)']
'''

# %%
'''from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
k_train, k_test, n_train, n_test = train_test_split(k, n, test_size=0.1, random_state=42)'''

# %%
'''knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(k_train, n_train)
#y_pred = knn.predict(x_test)'''
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
'''knn.score(k_test,n_test)'''
# Out:
# 0.9920346597264739

# %%
'''knn.score(k_train,n_train)'''
# Out:
# 0.995223978533908
